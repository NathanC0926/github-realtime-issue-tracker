# %%
# %load_ext sparksql_magic

from pyspark.sql import SparkSession

# Start Spark session
spark = SparkSession.builder \
    .appName("FilterGHJson") \
    .config("spark.sql.catalogImplementation", "hive") \
    .enableHiveSupport() \
    .getOrCreate()
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 25/02/20 11:03:32 WARN Utils: Your hostname, NathanBlade15 resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/02/20 11:03:32 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/02/20 11:03:32 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read.json("data/*.json.gz")
# Out:
# 25/02/20 11:05:39 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
df.printSchema()
df.show()
# Out:
# root
#  |-- actor: struct (nullable = true)
#  |    |-- avatar_url: string (nullable = true)
#  |    |-- display_login: string (nullable = true)
#  |    |-- gravatar_id: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- login: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- org: struct (nullable = true)
#  |    |-- avatar_url: string (nullable = true)
#  |    |-- gravatar_id: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- login: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- payload: struct (nullable = true)
#  |    |-- action: string (nullable = true)
#  |    |-- before: string (nullable = true)
#  |    |-- comment: struct (nullable = true)
#  |    |    |-- _links: struct (nullable = true)
#  |    |    |    |-- html: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- pull_request: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- self: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |-- author_association: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- commit_id: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- diff_hunk: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- in_reply_to_id: long (nullable = true)
#  |    |    |-- issue_url: string (nullable = true)
#  |    |    |-- line: long (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- original_commit_id: string (nullable = true)
#  |    |    |-- original_line: long (nullable = true)
#  |    |    |-- original_position: long (nullable = true)
#  |    |    |-- original_start_line: long (nullable = true)
#  |    |    |-- path: string (nullable = true)
#  |    |    |-- performed_via_github_app: struct (nullable = true)
#  |    |    |    |-- client_id: string (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- events: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- external_url: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- owner: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |    |-- permissions: struct (nullable = true)
#  |    |    |    |    |-- actions: string (nullable = true)
#  |    |    |    |    |-- actions_variables: string (nullable = true)
#  |    |    |    |    |-- administration: string (nullable = true)
#  |    |    |    |    |-- attestations: string (nullable = true)
#  |    |    |    |    |-- blocking: string (nullable = true)
#  |    |    |    |    |-- checks: string (nullable = true)
#  |    |    |    |    |-- codespaces: string (nullable = true)
#  |    |    |    |    |-- codespaces_lifecycle_admin: string (nullable = true)
#  |    |    |    |    |-- codespaces_metadata: string (nullable = true)
#  |    |    |    |    |-- codespaces_secrets: string (nullable = true)
#  |    |    |    |    |-- contents: string (nullable = true)
#  |    |    |    |    |-- dependabot_secrets: string (nullable = true)
#  |    |    |    |    |-- deployments: string (nullable = true)
#  |    |    |    |    |-- discussions: string (nullable = true)
#  |    |    |    |    |-- emails: string (nullable = true)
#  |    |    |    |    |-- environments: string (nullable = true)
#  |    |    |    |    |-- followers: string (nullable = true)
#  |    |    |    |    |-- gists: string (nullable = true)
#  |    |    |    |    |-- git_signing_ssh_public_keys: string (nullable = true)
#  |    |    |    |    |-- gpg_keys: string (nullable = true)
#  |    |    |    |    |-- interaction_limits: string (nullable = true)
#  |    |    |    |    |-- issues: string (nullable = true)
#  |    |    |    |    |-- keys: string (nullable = true)
#  |    |    |    |    |-- members: string (nullable = true)
#  |    |    |    |    |-- merge_queues: string (nullable = true)
#  |    |    |    |    |-- metadata: string (nullable = true)
#  |    |    |    |    |-- organization_actions_variables: string (nullable = true)
#  |    |    |    |    |-- organization_administration: string (nullable = true)
#  |    |    |    |    |-- organization_announcement_banners: string (nullable = true)
#  |    |    |    |    |-- organization_api_insights: string (nullable = true)
#  |    |    |    |    |-- organization_codespaces: string (nullable = true)
#  |    |    |    |    |-- organization_codespaces_secrets: string (nullable = true)
#  |    |    |    |    |-- organization_codespaces_settings: string (nullable = true)
#  |    |    |    |    |-- organization_copilot_seat_management: string (nullable = true)
#  |    |    |    |    |-- organization_custom_org_roles: string (nullable = true)
#  |    |    |    |    |-- organization_custom_properties: string (nullable = true)
#  |    |    |    |    |-- organization_custom_roles: string (nullable = true)
#  |    |    |    |    |-- organization_dependabot_secrets: string (nullable = true)
#  |    |    |    |    |-- organization_events: string (nullable = true)
#  |    |    |    |    |-- organization_hooks: string (nullable = true)
#  |    |    |    |    |-- organization_knowledge_bases: string (nullable = true)
#  |    |    |    |    |-- organization_packages: string (nullable = true)
#  |    |    |    |    |-- organization_personal_access_token_requests: string (nullable = true)
#  |    |    |    |    |-- organization_personal_access_tokens: string (nullable = true)
#  |    |    |    |    |-- organization_plan: string (nullable = true)
#  |    |    |    |    |-- organization_projects: string (nullable = true)
#  |    |    |    |    |-- organization_secrets: string (nullable = true)
#  |    |    |    |    |-- organization_self_hosted_runners: string (nullable = true)
#  |    |    |    |    |-- organization_user_blocking: string (nullable = true)
#  |    |    |    |    |-- packages: string (nullable = true)
#  |    |    |    |    |-- pages: string (nullable = true)
#  |    |    |    |    |-- plan: string (nullable = true)
#  |    |    |    |    |-- profile: string (nullable = true)
#  |    |    |    |    |-- pull_requests: string (nullable = true)
#  |    |    |    |    |-- repository_advisories: string (nullable = true)
#  |    |    |    |    |-- repository_custom_properties: string (nullable = true)
#  |    |    |    |    |-- repository_hooks: string (nullable = true)
#  |    |    |    |    |-- repository_projects: string (nullable = true)
#  |    |    |    |    |-- secret_scanning_alerts: string (nullable = true)
#  |    |    |    |    |-- secrets: string (nullable = true)
#  |    |    |    |    |-- security_events: string (nullable = true)
#  |    |    |    |    |-- single_file: string (nullable = true)
#  |    |    |    |    |-- starring: string (nullable = true)
#  |    |    |    |    |-- statuses: string (nullable = true)
#  |    |    |    |    |-- team_discussions: string (nullable = true)
#  |    |    |    |    |-- user_events: string (nullable = true)
#  |    |    |    |    |-- vulnerability_alerts: string (nullable = true)
#  |    |    |    |    |-- watching: string (nullable = true)
#  |    |    |    |    |-- workflows: string (nullable = true)
#  |    |    |    |-- slug: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- position: long (nullable = true)
#  |    |    |-- pull_request_review_id: long (nullable = true)
#  |    |    |-- pull_request_url: string (nullable = true)
#  |    |    |-- reactions: struct (nullable = true)
#  |    |    |    |-- +1: long (nullable = true)
#  |    |    |    |-- -1: long (nullable = true)
#  |    |    |    |-- confused: long (nullable = true)
#  |    |    |    |-- eyes: long (nullable = true)
#  |    |    |    |-- heart: long (nullable = true)
#  |    |    |    |-- hooray: long (nullable = true)
#  |    |    |    |-- laugh: long (nullable = true)
#  |    |    |    |-- rocket: long (nullable = true)
#  |    |    |    |-- total_count: long (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- side: string (nullable = true)
#  |    |    |-- start_line: long (nullable = true)
#  |    |    |-- start_side: string (nullable = true)
#  |    |    |-- subject_type: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- user_view_type: string (nullable = true)
#  |    |-- commits: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- author: struct (nullable = true)
#  |    |    |    |    |-- email: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- distinct: boolean (nullable = true)
#  |    |    |    |-- message: string (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- distinct_size: long (nullable = true)
#  |    |-- forkee: struct (nullable = true)
#  |    |    |-- allow_forking: boolean (nullable = true)
#  |    |    |-- archive_url: string (nullable = true)
#  |    |    |-- archived: boolean (nullable = true)
#  |    |    |-- assignees_url: string (nullable = true)
#  |    |    |-- blobs_url: string (nullable = true)
#  |    |    |-- branches_url: string (nullable = true)
#  |    |    |-- clone_url: string (nullable = true)
#  |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- commits_url: string (nullable = true)
#  |    |    |-- compare_url: string (nullable = true)
#  |    |    |-- contents_url: string (nullable = true)
#  |    |    |-- contributors_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- default_branch: string (nullable = true)
#  |    |    |-- deployments_url: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- disabled: boolean (nullable = true)
#  |    |    |-- downloads_url: string (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- fork: boolean (nullable = true)
#  |    |    |-- forks: long (nullable = true)
#  |    |    |-- forks_count: long (nullable = true)
#  |    |    |-- forks_url: string (nullable = true)
#  |    |    |-- full_name: string (nullable = true)
#  |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |-- git_url: string (nullable = true)
#  |    |    |-- has_discussions: boolean (nullable = true)
#  |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |-- has_projects: boolean (nullable = true)
#  |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |-- homepage: string (nullable = true)
#  |    |    |-- hooks_url: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- is_template: boolean (nullable = true)
#  |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |-- issues_url: string (nullable = true)
#  |    |    |-- keys_url: string (nullable = true)
#  |    |    |-- labels_url: string (nullable = true)
#  |    |    |-- language: string (nullable = true)
#  |    |    |-- languages_url: string (nullable = true)
#  |    |    |-- license: struct (nullable = true)
#  |    |    |    |-- key: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- spdx_id: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- merges_url: string (nullable = true)
#  |    |    |-- milestones_url: string (nullable = true)
#  |    |    |-- mirror_url: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- notifications_url: string (nullable = true)
#  |    |    |-- open_issues: long (nullable = true)
#  |    |    |-- open_issues_count: long (nullable = true)
#  |    |    |-- owner: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |-- private: boolean (nullable = true)
#  |    |    |-- public: boolean (nullable = true)
#  |    |    |-- pulls_url: string (nullable = true)
#  |    |    |-- pushed_at: string (nullable = true)
#  |    |    |-- releases_url: string (nullable = true)
#  |    |    |-- size: long (nullable = true)
#  |    |    |-- ssh_url: string (nullable = true)
#  |    |    |-- stargazers_count: long (nullable = true)
#  |    |    |-- stargazers_url: string (nullable = true)
#  |    |    |-- statuses_url: string (nullable = true)
#  |    |    |-- subscribers_url: string (nullable = true)
#  |    |    |-- subscription_url: string (nullable = true)
#  |    |    |-- svn_url: string (nullable = true)
#  |    |    |-- tags_url: string (nullable = true)
#  |    |    |-- teams_url: string (nullable = true)
#  |    |    |-- topics: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- trees_url: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- visibility: string (nullable = true)
#  |    |    |-- watchers: long (nullable = true)
#  |    |    |-- watchers_count: long (nullable = true)
#  |    |    |-- web_commit_signoff_required: boolean (nullable = true)
#  |    |-- head: string (nullable = true)
#  |    |-- issue: struct (nullable = true)
#  |    |    |-- active_lock_reason: string (nullable = true)
#  |    |    |-- assignee: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |-- assignees: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |-- author_association: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- closed_at: string (nullable = true)
#  |    |    |-- comments: long (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- draft: boolean (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- labels: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- color: string (nullable = true)
#  |    |    |    |    |-- default: boolean (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- labels_url: string (nullable = true)
#  |    |    |-- locked: boolean (nullable = true)
#  |    |    |-- milestone: struct (nullable = true)
#  |    |    |    |-- closed_at: string (nullable = true)
#  |    |    |    |-- closed_issues: long (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- creator: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- due_on: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- number: long (nullable = true)
#  |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- number: long (nullable = true)
#  |    |    |-- performed_via_github_app: struct (nullable = true)
#  |    |    |    |-- client_id: string (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- events: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- external_url: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- owner: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |    |-- permissions: struct (nullable = true)
#  |    |    |    |    |-- actions: string (nullable = true)
#  |    |    |    |    |-- checks: string (nullable = true)
#  |    |    |    |    |-- contents: string (nullable = true)
#  |    |    |    |    |-- discussions: string (nullable = true)
#  |    |    |    |    |-- emails: string (nullable = true)
#  |    |    |    |    |-- gists: string (nullable = true)
#  |    |    |    |    |-- issues: string (nullable = true)
#  |    |    |    |    |-- members: string (nullable = true)
#  |    |    |    |    |-- metadata: string (nullable = true)
#  |    |    |    |    |-- organization_projects: string (nullable = true)
#  |    |    |    |    |-- pages: string (nullable = true)
#  |    |    |    |    |-- pull_requests: string (nullable = true)
#  |    |    |    |    |-- repository_custom_properties: string (nullable = true)
#  |    |    |    |    |-- repository_hooks: string (nullable = true)
#  |    |    |    |    |-- repository_projects: string (nullable = true)
#  |    |    |    |    |-- security_events: string (nullable = true)
#  |    |    |    |    |-- starring: string (nullable = true)
#  |    |    |    |    |-- statuses: string (nullable = true)
#  |    |    |    |    |-- vulnerability_alerts: string (nullable = true)
#  |    |    |    |-- slug: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- pull_request: struct (nullable = true)
#  |    |    |    |-- diff_url: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- merged_at: string (nullable = true)
#  |    |    |    |-- patch_url: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- reactions: struct (nullable = true)
#  |    |    |    |-- +1: long (nullable = true)
#  |    |    |    |-- -1: long (nullable = true)
#  |    |    |    |-- confused: long (nullable = true)
#  |    |    |    |-- eyes: long (nullable = true)
#  |    |    |    |-- heart: long (nullable = true)
#  |    |    |    |-- hooray: long (nullable = true)
#  |    |    |    |-- laugh: long (nullable = true)
#  |    |    |    |-- rocket: long (nullable = true)
#  |    |    |    |-- total_count: long (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- repository_url: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- state_reason: string (nullable = true)
#  |    |    |-- sub_issues_summary: struct (nullable = true)
#  |    |    |    |-- completed: long (nullable = true)
#  |    |    |    |-- percent_completed: long (nullable = true)
#  |    |    |    |-- total: long (nullable = true)
#  |    |    |-- timeline_url: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- user_view_type: string (nullable = true)
#  |    |-- master_branch: string (nullable = true)
#  |    |-- member: struct (nullable = true)
#  |    |    |-- avatar_url: string (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- followers_url: string (nullable = true)
#  |    |    |-- following_url: string (nullable = true)
#  |    |    |-- gists_url: string (nullable = true)
#  |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- login: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- organizations_url: string (nullable = true)
#  |    |    |-- received_events_url: string (nullable = true)
#  |    |    |-- repos_url: string (nullable = true)
#  |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |-- starred_url: string (nullable = true)
#  |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user_view_type: string (nullable = true)
#  |    |-- number: long (nullable = true)
#  |    |-- pages: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- action: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- page_name: string (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- summary: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |-- pull_request: struct (nullable = true)
#  |    |    |-- _links: struct (nullable = true)
#  |    |    |    |-- comments: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- commits: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- html: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- issue: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- review_comment: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- review_comments: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- self: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- statuses: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |-- active_lock_reason: string (nullable = true)
#  |    |    |-- additions: long (nullable = true)
#  |    |    |-- assignee: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |-- assignees: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |-- author_association: string (nullable = true)
#  |    |    |-- auto_merge: struct (nullable = true)
#  |    |    |    |-- commit_message: string (nullable = true)
#  |    |    |    |-- commit_title: string (nullable = true)
#  |    |    |    |-- enabled_by: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |    |-- merge_method: string (nullable = true)
#  |    |    |-- base: struct (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- ref: string (nullable = true)
#  |    |    |    |-- repo: struct (nullable = true)
#  |    |    |    |    |-- allow_forking: boolean (nullable = true)
#  |    |    |    |    |-- archive_url: string (nullable = true)
#  |    |    |    |    |-- archived: boolean (nullable = true)
#  |    |    |    |    |-- assignees_url: string (nullable = true)
#  |    |    |    |    |-- blobs_url: string (nullable = true)
#  |    |    |    |    |-- branches_url: string (nullable = true)
#  |    |    |    |    |-- clone_url: string (nullable = true)
#  |    |    |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |    |    |-- comments_url: string (nullable = true)
#  |    |    |    |    |-- commits_url: string (nullable = true)
#  |    |    |    |    |-- compare_url: string (nullable = true)
#  |    |    |    |    |-- contents_url: string (nullable = true)
#  |    |    |    |    |-- contributors_url: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- default_branch: string (nullable = true)
#  |    |    |    |    |-- deployments_url: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- disabled: boolean (nullable = true)
#  |    |    |    |    |-- downloads_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- fork: boolean (nullable = true)
#  |    |    |    |    |-- forks: long (nullable = true)
#  |    |    |    |    |-- forks_count: long (nullable = true)
#  |    |    |    |    |-- forks_url: string (nullable = true)
#  |    |    |    |    |-- full_name: string (nullable = true)
#  |    |    |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |    |    |-- git_url: string (nullable = true)
#  |    |    |    |    |-- has_discussions: boolean (nullable = true)
#  |    |    |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |    |    |-- has_projects: boolean (nullable = true)
#  |    |    |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |    |    |-- homepage: string (nullable = true)
#  |    |    |    |    |-- hooks_url: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- is_template: boolean (nullable = true)
#  |    |    |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |    |    |-- issues_url: string (nullable = true)
#  |    |    |    |    |-- keys_url: string (nullable = true)
#  |    |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |    |-- language: string (nullable = true)
#  |    |    |    |    |-- languages_url: string (nullable = true)
#  |    |    |    |    |-- license: struct (nullable = true)
#  |    |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- spdx_id: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- merges_url: string (nullable = true)
#  |    |    |    |    |-- milestones_url: string (nullable = true)
#  |    |    |    |    |-- mirror_url: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- notifications_url: string (nullable = true)
#  |    |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |    |-- open_issues_count: long (nullable = true)
#  |    |    |    |    |-- owner: struct (nullable = true)
#  |    |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |    |    |-- private: boolean (nullable = true)
#  |    |    |    |    |-- pulls_url: string (nullable = true)
#  |    |    |    |    |-- pushed_at: string (nullable = true)
#  |    |    |    |    |-- releases_url: string (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- ssh_url: string (nullable = true)
#  |    |    |    |    |-- stargazers_count: long (nullable = true)
#  |    |    |    |    |-- stargazers_url: string (nullable = true)
#  |    |    |    |    |-- statuses_url: string (nullable = true)
#  |    |    |    |    |-- subscribers_url: string (nullable = true)
#  |    |    |    |    |-- subscription_url: string (nullable = true)
#  |    |    |    |    |-- svn_url: string (nullable = true)
#  |    |    |    |    |-- tags_url: string (nullable = true)
#  |    |    |    |    |-- teams_url: string (nullable = true)
#  |    |    |    |    |-- topics: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- trees_url: string (nullable = true)
#  |    |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- visibility: string (nullable = true)
#  |    |    |    |    |-- watchers: long (nullable = true)
#  |    |    |    |    |-- watchers_count: long (nullable = true)
#  |    |    |    |    |-- web_commit_signoff_required: boolean (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- user: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- changed_files: long (nullable = true)
#  |    |    |-- closed_at: string (nullable = true)
#  |    |    |-- comments: long (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- commits: long (nullable = true)
#  |    |    |-- commits_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- deletions: long (nullable = true)
#  |    |    |-- diff_url: string (nullable = true)
#  |    |    |-- draft: boolean (nullable = true)
#  |    |    |-- head: struct (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- ref: string (nullable = true)
#  |    |    |    |-- repo: struct (nullable = true)
#  |    |    |    |    |-- allow_forking: boolean (nullable = true)
#  |    |    |    |    |-- archive_url: string (nullable = true)
#  |    |    |    |    |-- archived: boolean (nullable = true)
#  |    |    |    |    |-- assignees_url: string (nullable = true)
#  |    |    |    |    |-- blobs_url: string (nullable = true)
#  |    |    |    |    |-- branches_url: string (nullable = true)
#  |    |    |    |    |-- clone_url: string (nullable = true)
#  |    |    |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |    |    |-- comments_url: string (nullable = true)
#  |    |    |    |    |-- commits_url: string (nullable = true)
#  |    |    |    |    |-- compare_url: string (nullable = true)
#  |    |    |    |    |-- contents_url: string (nullable = true)
#  |    |    |    |    |-- contributors_url: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- default_branch: string (nullable = true)
#  |    |    |    |    |-- deployments_url: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- disabled: boolean (nullable = true)
#  |    |    |    |    |-- downloads_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- fork: boolean (nullable = true)
#  |    |    |    |    |-- forks: long (nullable = true)
#  |    |    |    |    |-- forks_count: long (nullable = true)
#  |    |    |    |    |-- forks_url: string (nullable = true)
#  |    |    |    |    |-- full_name: string (nullable = true)
#  |    |    |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |    |    |-- git_url: string (nullable = true)
#  |    |    |    |    |-- has_discussions: boolean (nullable = true)
#  |    |    |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |    |    |-- has_projects: boolean (nullable = true)
#  |    |    |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |    |    |-- homepage: string (nullable = true)
#  |    |    |    |    |-- hooks_url: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- is_template: boolean (nullable = true)
#  |    |    |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |    |    |-- issues_url: string (nullable = true)
#  |    |    |    |    |-- keys_url: string (nullable = true)
#  |    |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |    |-- language: string (nullable = true)
#  |    |    |    |    |-- languages_url: string (nullable = true)
#  |    |    |    |    |-- license: struct (nullable = true)
#  |    |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- spdx_id: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- merges_url: string (nullable = true)
#  |    |    |    |    |-- milestones_url: string (nullable = true)
#  |    |    |    |    |-- mirror_url: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- notifications_url: string (nullable = true)
# ...
#  |    |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- due_on: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- number: long (nullable = true)
#  |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- number: long (nullable = true)
#  |    |    |-- patch_url: string (nullable = true)
#  |    |    |-- rebaseable: boolean (nullable = true)
#  |    |    |-- requested_reviewers: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |-- requested_teams: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- members_url: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- notification_setting: string (nullable = true)
#  |    |    |    |    |-- parent: string (nullable = true)
#  |    |    |    |    |-- permission: string (nullable = true)
#  |    |    |    |    |-- privacy: string (nullable = true)
#  |    |    |    |    |-- repositories_url: string (nullable = true)
#  |    |    |    |    |-- slug: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- review_comment_url: string (nullable = true)
#  |    |    |-- review_comments: long (nullable = true)
#  |    |    |-- review_comments_url: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- statuses_url: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- user_view_type: string (nullable = true)
#  |    |-- push_id: long (nullable = true)
#  |    |-- pusher_type: string (nullable = true)
#  |    |-- ref: string (nullable = true)
#  |    |-- ref_type: string (nullable = true)
#  |    |-- release: struct (nullable = true)
#  |    |    |-- assets: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- browser_download_url: string (nullable = true)
#  |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- download_count: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |    |-- uploader: struct (nullable = true)
#  |    |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- assets_url: string (nullable = true)
#  |    |    |-- author: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- user_view_type: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- discussion_url: string (nullable = true)
#  |    |    |-- draft: boolean (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- is_short_description_html_truncated: boolean (nullable = true)
#  |    |    |-- mentions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- avatar_user_actor: boolean (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- profile_name: string (nullable = true)
#  |    |    |    |    |-- profile_url: string (nullable = true)
#  |    |    |-- mentions_count: long (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- prerelease: boolean (nullable = true)
#  |    |    |-- published_at: string (nullable = true)
#  |    |    |-- reactions: struct (nullable = true)
#  |    |    |    |-- +1: long (nullable = true)
#  |    |    |    |-- -1: long (nullable = true)
#  |    |    |    |-- confused: long (nullable = true)
#  |    |    |    |-- eyes: long (nullable = true)
#  |    |    |    |-- heart: long (nullable = true)
#  |    |    |    |-- hooray: long (nullable = true)
#  |    |    |    |-- laugh: long (nullable = true)
#  |    |    |    |-- rocket: long (nullable = true)
#  |    |    |    |-- total_count: long (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- short_description_html: string (nullable = true)
#  |    |    |-- tag_name: string (nullable = true)
#  |    |    |-- tarball_url: string (nullable = true)
#  |    |    |-- target_commitish: string (nullable = true)
#  |    |    |-- upload_url: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- zipball_url: string (nullable = true)
#  |    |-- repository_id: long (nullable = true)
#  |    |-- review: struct (nullable = true)
#  |    |    |-- _links: struct (nullable = true)
#  |    |    |    |-- html: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- pull_request: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |-- author_association: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- commit_id: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- pull_request_url: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- submitted_at: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- user_view_type: string (nullable = true)
#  |    |-- size: long (nullable = true)
#  |-- public: boolean (nullable = true)
#  |-- repo: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- type: string (nullable = true)
# [Stage 1:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+-----------+--------------------+--------------------+------+--------------------+-----------------+
# |               actor|          created_at|         id|                 org|             payload|public|                repo|             type|
# +--------------------+--------------------+-----------+--------------------+--------------------+------+--------------------+-----------------+
# |{https://avatars....|2025-01-01T01:00:00Z|45186095831|                NULL|{created, NULL, {...|  true|{810155444, aws-a...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095832|                NULL|{NULL, 1c0bb7ae07...|  true|{314538798, Malee...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095834|                NULL|{NULL, c2e22ed422...|  true|{463061974, phanu...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095837|                NULL|{NULL, 40f81c7a80...|  true|{894756355, plume...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095840|{https://avatars....|{NULL, 9f5dc49667...|  true|{675878981, khuln...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095841|{https://avatars....|{NULL, e147eff3c4...|  true|{358953911, mycod...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095842|{https://avatars....|{NULL, 1c7f3fed53...|  true|{741138445, defen...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095845|{https://avatars....|{started, NULL, N...|  true|{285412527, RavEn...|       WatchEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095846|                NULL|{NULL, 5757a34349...|  true|{363439067, Nepha...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095853|{https://avatars....|{NULL, NULL, NULL...|  true|{554140954, FCL-T...|      CreateEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095858|                NULL|{NULL, 7e0a6764f5...|  true|{701808980, JustD...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095860|{https://avatars....|{NULL, NULL, NULL...|  true|{358953911, mycod...|      DeleteEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095861|                NULL|{NULL, 1c0bb7ae07...|  true|{531251198, Eduar...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095862|                NULL|{NULL, 5225745534...|  true|{906673568, teoch...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095864|{https://avatars....|{started, NULL, N...|  true|{708266011, Autom...|       WatchEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095865|                NULL|{NULL, 1f6032658c...|  true|{804064047, rcedg...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095867|                NULL|{NULL, 9557bed8cd...|  true|{909555426, igjer...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095869|                NULL|{NULL, b741474558...|  true|{792476510, Kevin...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095871|                NULL|{NULL, ca3c3471fc...|  true|{776879165, 3yed8...|        PushEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095877|                NULL|{NULL, 211b25ef1d...|  true|{321533079, ryanL...|        PushEvent|
# +--------------------+--------------------+-----------+--------------------+--------------------+------+--------------------+-----------------+
# only showing top 20 rows

# %%
df = df.filter(df["type"].isin("IssuesEvent", "IssueCommentEvent"))

# %%
df.createOrReplaceTempView("df")

# %%
df.show(20)
# Out:
# +--------------------+--------------------+-----------+--------------------+--------------------+------+--------------------+-----------------+
# |               actor|          created_at|         id|                 org|             payload|public|                repo|             type|
# +--------------------+--------------------+-----------+--------------------+--------------------+------+--------------------+-----------------+
# |{https://avatars....|2025-01-01T01:00:00Z|45186095831|                NULL|{created, NULL, {...|  true|{810155444, aws-a...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:00Z|45186095924|                NULL|{created, NULL, {...|  true|{841034127, hisRo...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:02Z|45186096107|                NULL|{opened, NULL, NU...|  true|{645980442, mo9a7...|      IssuesEvent|
# |{https://avatars....|2025-01-01T01:00:02Z|45186096114|                NULL|{created, NULL, {...|  true|{773201949, s-hir...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:02Z|45186096173|                NULL|{opened, NULL, NU...|  true|{606520610, Purfv...|      IssuesEvent|
# |{https://avatars....|2025-01-01T01:00:04Z|45186096455|                NULL|{opened, NULL, NU...|  true|{903529255, carol...|      IssuesEvent|
# |{https://avatars....|2025-01-01T01:00:04Z|45186096537|                NULL|{closed, NULL, NU...|  true|{439100086, Price...|      IssuesEvent|
# |{https://avatars....|2025-01-01T01:00:04Z|45186096592|{https://avatars....|{created, NULL, {...|  true|{65772720, docker...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:04Z|45186096631|{https://avatars....|{opened, NULL, NU...|  true|{737476680, WEID-...|      IssuesEvent|
# |{https://avatars....|2025-01-01T01:00:05Z|45186096796|{https://avatars....|{created, NULL, {...|  true|{699532645, astra...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:05Z|45186096907|                NULL|{created, NULL, {...|  true|{439100086, Price...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:05Z|45186096911|                NULL|{created, NULL, {...|  true|{812033242, aws-a...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:06Z|45186097042|                NULL|{created, NULL, {...|  true|{810155416, aws-a...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:07Z|45186097380|                NULL|{created, NULL, {...|  true|{882090668, TheDa...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:08Z|45186097438|{https://avatars....|{created, NULL, {...|  true|{699532645, astra...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:08Z|45186097533|{https://avatars....|{created, NULL, {...|  true|{12285928, backdr...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:08Z|45186097554|                NULL|{opened, NULL, NU...|  true|{670803275, lino-...|      IssuesEvent|
# |{https://avatars....|2025-01-01T01:00:09Z|45186097660|                NULL|{created, NULL, {...|  true|{538042471, Sapta...|IssueCommentEvent|
# |{https://avatars....|2025-01-01T01:00:09Z|45186097791|{https://avatars....|{opened, NULL, NU...|  true|{864974606, tazat...|      IssuesEvent|
# |{https://avatars....|2025-01-01T01:00:11Z|45186098010|{https://avatars....|{created, NULL, {...|  true|{7910045, badges/...|IssueCommentEvent|
# +--------------------+--------------------+-----------+--------------------+--------------------+------+--------------------+-----------------+
# only showing top 20 rows

# %%
# %%sparksql
# SELECT repo.* FROM df
# Out:
# only showing top 20 row(s)
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">id</td><td style="font-weight: bold">name</td><td style="font-weight: bold">url</td></tr><tr><td>810155444</td><td>aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2</td><td>https://api.github.com/repos/aws-aemilia-pdx/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-us-west-2</td></tr><tr><td>841034127</td><td>hisRoyalty/hrbs-drills</td><td>https://api.github.com/repos/hisRoyalty/hrbs-drills</td></tr><tr><td>645980442</td><td>mo9a7i/time_now</td><td>https://api.github.com/repos/mo9a7i/time_now</td></tr><tr><td>773201949</td><td>s-hirano-ist/s-private</td><td>https://api.github.com/repos/s-hirano-ist/s-private</td></tr><tr><td>606520610</td><td>Purfview/whisper-standalone-win</td><td>https://api.github.com/repos/Purfview/whisper-standalone-win</td></tr><tr><td>903529255</td><td>caroluarjf/CleanSweep</td><td>https://api.github.com/repos/caroluarjf/CleanSweep</td></tr><tr><td>439100086</td><td>PricelessToolkit/Droplet</td><td>https://api.github.com/repos/PricelessToolkit/Droplet</td></tr><tr><td>65772720</td><td>docker/docs</td><td>https://api.github.com/repos/docker/docs</td></tr><tr><td>737476680</td><td>WEID-Consortium/weid.info</td><td>https://api.github.com/repos/WEID-Consortium/weid.info</td></tr><tr><td>699532645</td><td>astral-sh/uv</td><td>https://api.github.com/repos/astral-sh/uv</td></tr><tr><td>439100086</td><td>PricelessToolkit/Droplet</td><td>https://api.github.com/repos/PricelessToolkit/Droplet</td></tr><tr><td>812033242</td><td>aws-aemilia-kix/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-prod-ap-northeast-3</td><td>https://api.github.com/repos/aws-aemilia-kix/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-prod-ap-northeast-3</td></tr><tr><td>810155416</td><td>aws-aemilia-fra/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-eu-central-1</td><td>https://api.github.com/repos/aws-aemilia-fra/Github-PR-Commit-Integration-Test-DoNotTouch-GitH-MJCD6L4M-v1-preprod-eu-central-1</td></tr><tr><td>882090668</td><td>TheDarkPeasant/Illage-and-Spillage--Respillaged</td><td>https://api.github.com/repos/TheDarkPeasant/Illage-and-Spillage--Respillaged</td></tr><tr><td>699532645</td><td>astral-sh/uv</td><td>https://api.github.com/repos/astral-sh/uv</td></tr><tr><td>12285928</td><td>backdrop/backdrop</td><td>https://api.github.com/repos/backdrop/backdrop</td></tr><tr><td>670803275</td><td>lino-levan/astral</td><td>https://api.github.com/repos/lino-levan/astral</td></tr><tr><td>538042471</td><td>SaptarshiSarkar12/Drifty</td><td>https://api.github.com/repos/SaptarshiSarkar12/Drifty</td></tr><tr><td>864974606</td><td>tazatechnology/flutter-tailwind-ui</td><td>https://api.github.com/repos/tazatechnology/flutter-tailwind-ui</td></tr><tr><td>7910045</td><td>badges/shields</td><td>https://api.github.com/repos/badges/shields</td></tr></table>

# %%
spark.sql("""
          SELECT payload.issue.* FROM df
          where type = 'IssuesEvent'
          """).show(20)
# Out:
# 25/02/20 11:08:08 WARN HiveConf: HiveConf of name hive.stats.jdbc.timeout does not exist
# 25/02/20 11:08:08 WARN HiveConf: HiveConf of name hive.stats.retries.wait does not exist
# 25/02/20 11:08:11 WARN ObjectStore: Version information not found in metastore. hive.metastore.schema.verification is not enabled so recording the schema version 2.3.0
# 25/02/20 11:08:11 WARN ObjectStore: setMetaStoreSchemaVersion called but recording version is disabled: version = 2.3.0, comment = Set by MetaStore nathanblade15@127.0.1.1
# 25/02/20 11:08:11 WARN ObjectStore: Failed to get database default, returning NoSuchObjectException
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 spark.sql("""
#       2           SELECT payload.issue.* FROM df
#       3           where type = 'IssuesEvent'
#       4           """).show(20)
#
# File ~/github-realtime-issue-tracker/venv/lib/python3.12/site-packages/pyspark/sql/session.py:1631, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#    1627         assert self._jvm is not None
#    1628         litArgs = self._jvm.PythonUtils.toArray(
#    1629             [_to_java_column(lit(v)) for v in (args or [])]
#    1630         )
# -> 1631     return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1632 finally:
#    1633     if len(kwargs) > 0:
#
# File ~/github-realtime-issue-tracker/venv/lib/python3.12/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/github-realtime-issue-tracker/venv/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [TABLE_OR_VIEW_NOT_FOUND] The table or view `df` cannot be found. Verify the spelling and correctness of the schema and catalog.
# If you did not qualify the name with a schema, verify the current_schema() output, or qualify the name with the correct schema and catalog.
# To tolerate the error on drop use DROP VIEW IF EXISTS or DROP TABLE IF EXISTS.; line 2 pos 38;
# 'Project [payload.issue.*]
# +- 'Filter ('type = IssuesEvent)
#    +- 'UnresolvedRelation [df], [], false

# %%
spark.sql("""
          SELECT payload.* FROM df
          where type = 'IssueCommentEvent' or type = 'IssuesEvent'
          """).show(20)
# Out:
# +-------+------+--------------------+-------+-----------+-------------+------+----+--------------------+-------------+------+------+-----+------------+-------+-----------+----+--------+-------+-------------+------+----+
# | action|before|             comment|commits|description|distinct_size|forkee|head|               issue|master_branch|member|number|pages|pull_request|push_id|pusher_type| ref|ref_type|release|repository_id|review|size|
# +-------+------+--------------------+-------+-----------+-------------+------+----+--------------------+-------------+------+------+-----+------------+-------+-----------+----+--------+-------+-------------+------+----+
# |created|  NULL|{NULL, NONE, This...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, NONE, vers...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# | opened|  NULL|                NULL|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, NONE, <!--...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# | opened|  NULL|                NULL|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# | opened|  NULL|                NULL|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# | closed|  NULL|                NULL|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, NONE, Ther...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# | opened|  NULL|                NULL|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, MEMBER, So...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, {https://a...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, NONE, Oh o...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, NONE, This...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, NONE, This...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, OWNER, Who...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, NONE, I ca...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, COLLABORAT...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# | opened|  NULL|                NULL|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, NONE, [vc]...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# | opened|  NULL|                NULL|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# |created|  NULL|{NULL, NONE, Hi c...|   NULL|       NULL|         NULL|  NULL|NULL|{NULL, NULL, [], ...|         NULL|  NULL|  NULL| NULL|        NULL|   NULL|       NULL|NULL|    NULL|   NULL|         NULL|  NULL|NULL|
# +-------+------+--------------------+-------+-----------+-------------+------+----+--------------------+-------------+------+------+-----+------------+-------+-----------+----+--------+-------+-------------+------+----+
# only showing top 20 rows

# %%
spark.sql("""
          SELECT payload.issue.* FROM df
          where type = 'IssueCommentEvent'
          """).show(20,True)
# Out:
# +------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------+--------------------+--------------------+-----+--------------------+--------------------+----------+--------------------+--------------------+------+---------+--------------------+------+------------------------+--------------------+--------------------+--------------------+------+------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |active_lock_reason|            assignee|           assignees|author_association|                body|           closed_at|comments|        comments_url|          created_at|draft|          events_url|            html_url|        id|              labels|          labels_url|locked|milestone|             node_id|number|performed_via_github_app|        pull_request|           reactions|      repository_url| state|state_reason|sub_issues_summary|        timeline_url|               title|          updated_at|                 url|                user|
# +------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------+--------------------+--------------------+-----+--------------------+--------------------+----------+--------------------+--------------------+------+---------+--------------------+------+------------------------+--------------------+--------------------+--------------------+------+------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |              NULL|                NULL|                  []|             OWNER|Automated test pu...|                NULL|       1|https://api.githu...|2025-01-01T00:58:50Z|false|https://api.githu...|https://github.co...|2764758186|                  []|https://api.githu...| false|     NULL| PR_kwDOMEn9tM6Gg8Xc| 20224|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|Automated test pu...|2025-01-01T00:59:59Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|              NONE|I'm having some i...|                NULL|       2|https://api.githu...|2024-12-31T06:58:34Z| NULL|https://api.githu...|https://github.co...|2764032095|                  []|https://api.githu...| false|     NULL|  I_kwDOMiEpj86kv8hf|     1|                    NULL|                NULL|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|Mining straight d...|2025-01-01T01:00:00Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|             OWNER|                NULL|                NULL|       1|https://api.githu...|2025-01-01T00:59:53Z|false|https://api.githu...|https://github.co...|2764758614|                  []|https://api.githu...| false|     NULL| PR_kwDOLhYgHc6Gg8dE|   819|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|refactor: 💡 chan...|2025-01-01T01:00:02Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|              NONE|### Is this a doc...|                NULL|       1|https://api.githu...|2024-10-03T02:40:51Z| NULL|https://api.githu...|https://github.co...|2562989299|[{c6f6ff, false, ...|https://api.githu...| false|     NULL|  I_kwDOA-ucsM6YxBzz| 21051|                    NULL|                NULL|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|         {0, 0, 0}|https://api.githu...|Missing documenta...|2025-01-01T01:00:04Z|https://api.githu...|{https://avatars....|
# |              NULL|{https://avatars....|[{https://avatars...|              NONE|When a project us...|                NULL|       3|https://api.githu...|2024-12-31T16:47:45Z| NULL|https://api.githu...|https://github.co...|2764536755|[{A14A61, false, ...|https://api.githu...| false|     NULL|  I_kwDOKbIFZc6kx3uz| 10255|                    NULL|                NULL|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|         {0, 0, 0}|https://api.githu...|Bug: Circular dep...|2025-01-01T01:00:05Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|              NONE|When I use the ph...|2025-01-01T01:00:03Z|       3|https://api.githu...|2024-12-31T23:42:35Z| NULL|https://api.githu...|https://github.co...|2764728177|                  []|https://api.githu...| false|     NULL|  I_kwDOGiwits6kymdx|    22|                    NULL|                NULL|{0, 0, 0, 0, 0, 0...|https://api.githu...|closed|   completed|              NULL|https://api.githu...|Pumps turning off...|2025-01-01T01:00:03Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|             OWNER|Automated test pu...|                NULL|       1|https://api.githu...|2025-01-01T00:58:56Z|false|https://api.githu...|https://github.co...|2764758219|                  []|https://api.githu...| false|     NULL| PR_kwDOMGak2s6Gg8X4| 19887|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|Automated test pu...|2025-01-01T01:00:05Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|             OWNER|Automated test pu...|                NULL|       1|https://api.githu...|2025-01-01T00:58:51Z|false|https://api.githu...|https://github.co...|2764758188|                  []|https://api.githu...| false|     NULL| PR_kwDOMEn9mM6Gg8Xe| 20219|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|Automated test pu...|2025-01-01T01:00:05Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|              NONE|=\r\n[crash-2024-...|                NULL|       3|https://api.githu...|2024-12-30T04:52:28Z| NULL|https://api.githu...|https://github.co...|2762646139|                  []|https://api.githu...| false|     NULL|  I_kwDONJOirM6kqqJ7|    11|                    NULL|                NULL|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|    reopened|              NULL|https://api.githu...|Issue with enginn...|2025-01-01T01:00:07Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|              NONE|Hi there, I'm usi...|                NULL|      14|https://api.githu...|2024-12-15T23:44:56Z| NULL|https://api.githu...|https://github.co...|2740992919|[{FBCA04, false, ...|https://api.githu...| false|     NULL|  I_kwDOKbIFZc6jYDuX|  9923|                    NULL|                NULL|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|         {0, 0, 0}|https://api.githu...|uv.lock does not ...|2025-01-01T01:00:07Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|       CONTRIBUTOR|Fixes https://git...|                NULL|       1|https://api.githu...|2024-12-28T02:02:21Z|false|https://api.githu...|https://github.co...|2761394543|                  []|https://api.githu...| false|     NULL| PR_kwDOALt36M6GVxN1|  4957|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|Issue 6570. Alter...|2025-01-01T01:00:08Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|       CONTRIBUTOR|Bumps the openrew...|                NULL|       1|https://api.githu...|2025-01-01T01:00:03Z|false|https://api.githu...|https://github.co...|2764758672|[{0052cc, false, ...|https://api.githu...| false|     NULL| PR_kwDOIBHgZ86Gg8dz|   752|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|chore(maven): bum...|2025-01-01T01:00:08Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|              NONE|:question: **Ques...|                NULL|      15|https://api.githu...|2019-10-05T01:42:35Z| NULL|https://api.githu...|https://github.co...| 502900694|[{c5def5, false, ...|https://api.githu...| false|     NULL|MDU6SXNzdWU1MDI5M...|  4140|                    NULL|                NULL|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|Support Arabic te...|2025-01-01T01:00:10Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|       CONTRIBUTOR|This PR contains ...|                NULL|       1|https://api.githu...|2025-01-01T00:58:43Z|false|https://api.githu...|https://github.co...|2764758139|                  []|https://api.githu...| false|     NULL| PR_kwDOEyH2ec6Gg8Wy|   596|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|fix(deps): update...|2025-01-01T01:00:11Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|       CONTRIBUTOR|## Motivation\n\n...|                NULL|       2|https://api.githu...|2024-12-27T15:48:01Z|false|https://api.githu...|https://github.co...|2761030705|                  []|https://api.githu...| false|     NULL| PR_kwDOBnWgr86GUjHv|  6575|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|sql: remove epoch...|2025-01-01T01:00:12Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|            MEMBER|                NULL|2025-01-01T01:00:11Z|       5|https://api.githu...|2024-12-31T21:25:15Z|false|https://api.githu...|https://github.co...|2764682513|                  []|https://api.githu...| false|     NULL| PR_kwDOE2WLFM6GgtLd|  2773|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|closed|        NULL|              NULL|https://api.githu...|Replace runComman...|2025-01-01T01:00:12Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|       CONTRIBUTOR|Bumps [Microsoft....|2025-01-01T01:00:10Z|       1|https://api.githu...|2024-11-05T19:44:11Z|false|https://api.githu...|https://github.co...|2636320984|[{0366d6, false, ...|https://api.githu...| false|     NULL| PR_kwDONK9cKc6A-Ns4|     5|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|closed|        NULL|              NULL|https://api.githu...|build(deps): Bump...|2025-01-01T01:00:12Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|              NONE|Bumps golang from...|2025-01-01T01:00:12Z|       1|https://api.githu...|2024-12-01T00:47:47Z|false|https://api.githu...|https://github.co...|2708301936|[{0366d6, false, ...|https://api.githu...| false|     NULL| PR_kwDOEY8wR86DpS0N|   276|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|closed|        NULL|              NULL|https://api.githu...|chore(deps): bump...|2025-01-01T01:00:12Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|       CONTRIBUTOR|                 wip|                NULL|       1|https://api.githu...|2025-01-01T01:00:09Z| true|https://api.githu...|https://github.co...|2764758720|                  []|https://api.githu...| false|     NULL| PR_kwDOMzt-pM6Gg8eY|   231|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|chore: improve in...|2025-01-01T01:00:13Z|https://api.githu...|{https://avatars....|
# |              NULL|                NULL|                  []|       CONTRIBUTOR|Bumps [cookie](ht...|                NULL|       3|https://api.githu...|2024-12-01T00:32:44Z|false|https://api.githu...|https://github.co...|2708294902|[{3CBF00, false, ...|https://api.githu...| false|     NULL| PR_kwDOCB7CQs6DpRYx|  2092|                    NULL|{https://github.c...|{0, 0, 0, 0, 0, 0...|https://api.githu...|  open|        NULL|              NULL|https://api.githu...|Bump cookie, nuxt...|2025-01-01T01:00:13Z|https://api.githu...|{https://avatars....|
# +------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------+--------------------+--------------------+-----+--------------------+--------------------+----------+--------------------+--------------------+------+---------+--------------------+------+------------------------+--------------------+--------------------+--------------------+------+------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
spark.sql("""
          SELECT payload.issue.user.* FROM df
          where type = 'IssueCommentEvent'
          """).show(20,True)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+---------+---------------+--------------------+--------------------+--------------------+--------------------+----------+--------------------+--------------------+----+--------------------+--------------+
# |          avatar_url|          events_url|       followers_url|       following_url|           gists_url|gravatar_id|            html_url|       id|          login|             node_id|   organizations_url| received_events_url|           repos_url|site_admin|         starred_url|   subscriptions_url|type|                 url|user_view_type|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+---------+---------------+--------------------+--------------------+--------------------+--------------------+----------+--------------------+--------------------+----+--------------------+--------------+
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...|104660922|aws-aemilia-pdx|        U_kgDOBjz_ug|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...|193308163|  DirtyRedPanda|        U_kgDOC4WmAw|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...| 88515957|   s-hirano-ist|MDQ6VXNlcjg4NTE1OTU3|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...| 22638037|       pandaxtc|MDQ6VXNlcjIyNjM4MDM3|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...|108596565|  CarrotManMatt|        U_kgDOBnkNVQ|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...| 51205370|       avrabi19|MDQ6VXNlcjUxMjA1Mzcw|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...|104595665|aws-aemilia-kix|        U_kgDOBjwA0Q|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...|104585684|aws-aemilia-fra|        U_kgDOBjvZ1A|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...|112207118|     Lincolnium|        U_kgDOBrAlDg|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...|  6856673|        zackees|MDQ6VXNlcjY4NTY2NzM=|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...|  9938978|     argiepiano|MDQ6VXNlcjk5Mzg5Nzg=|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...| 49699333|dependabot[bot]|MDM6Qm90NDk2OTkzMzM=|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...| Bot|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...| 20658625| Aissaoui-Ahmed|MDQ6VXNlcjIwNjU4NjI1|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...| 29139614|  renovate[bot]|MDM6Qm90MjkxMzk2MTQ=|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...| Bot|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...|   190448|        ivan4th|MDQ6VXNlcjE5MDQ0OA==|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...|  7258858|SuperSandro2000|MDQ6VXNlcjcyNTg4NTg=|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...| 49699333|dependabot[bot]|MDM6Qm90NDk2OTkzMzM=|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...| Bot|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...| 49699333|dependabot[bot]|MDM6Qm90NDk2OTkzMzM=|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...| Bot|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...| 57758277|        amk-dev|MDQ6VXNlcjU3NzU4Mjc3|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...|User|https://api.githu...|        public|
# |https://avatars.g...|https://api.githu...|https://api.githu...|https://api.githu...|https://api.githu...|           |https://github.co...| 49699333|dependabot[bot]|MDM6Qm90NDk2OTkzMzM=|https://api.githu...|https://api.githu...|https://api.githu...|     false|https://api.githu...|https://api.githu...| Bot|https://api.githu...|        public|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+---------+---------------+--------------------+--------------------+--------------------+--------------------+----------+--------------------+--------------------+----+--------------------+--------------+
# only showing top 20 rows

# %%
# %%sparksql
# SELECT
#     created_at,
#     payload.issue.author_association,
#     payload.action,
#     payload.issue.closed_at,
#     payload.issue.title,
#     payload.issue.id,
#     payload.issue.labels,
#     payload.issue.state,
#     payload.issue.state_reason
# FROM df
# WHERE (payload.action = 'opened' OR payload.action = 'reopened')
#     AND type = 'IssuesEvent' AND payload.issue.closed_at IS NOT NULL
# Out:
# [Stage 12:==============>                                           (1 + 3) / 4]
# only showing top 20 row(s)
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">created_at</td><td style="font-weight: bold">author_association</td><td style="font-weight: bold">action</td><td style="font-weight: bold">closed_at</td><td style="font-weight: bold">title</td><td style="font-weight: bold">id</td><td style="font-weight: bold">labels</td><td style="font-weight: bold">state</td><td style="font-weight: bold">state_reason</td></tr><tr><td>2025-01-01T01:05:06Z</td><td>OWNER</td><td>opened</td><td>2025-01-01T01:05:04Z</td><td>🚨 Error Report - 2025. 01. 01. 01:05:03</td><td>2764760625</td><td>[Row(color=&#x27;ededed&#x27;, default=False, description=None, id=7568837120, name=&#x27;health&#x27;, node_id=&#x27;LA_kwDOGKB-P88AAAABwyNKAA&#x27;, url=&#x27;https://api.github.com/repos/RWB0104/RWB0104.github.io/labels/health&#x27;), Row(color=&#x27;ededed&#x27;, default=False, description=None, id=7568837121, name=&#x27;prod&#x27;, node_id=&#x27;LA_kwDOGKB-P88AAAABwyNKAQ&#x27;, url=&#x27;https://api.github.com/repos/RWB0104/RWB0104.github.io/labels/prod&#x27;)]</td><td>closed</td><td>completed</td></tr><tr><td>2025-01-01T01:25:41Z</td><td>NONE</td><td>opened</td><td>2025-01-01T01:25:40Z</td><td>20250101</td><td>2764768270</td><td>[]</td><td>closed</td><td>completed</td></tr><tr><td>2025-01-01T12:23:25Z</td><td>OWNER</td><td>opened</td><td>2025-01-01T12:23:24Z</td><td>🚨 Error Report - 2025. 01. 01. 12:23:23</td><td>2765039832</td><td>[Row(color=&#x27;ededed&#x27;, default=False, description=None, id=7568837120, name=&#x27;health&#x27;, node_id=&#x27;LA_kwDOGKB-P88AAAABwyNKAA&#x27;, url=&#x27;https://api.github.com/repos/RWB0104/RWB0104.github.io/labels/health&#x27;), Row(color=&#x27;ededed&#x27;, default=False, description=None, id=7568837121, name=&#x27;prod&#x27;, node_id=&#x27;LA_kwDOGKB-P88AAAABwyNKAQ&#x27;, url=&#x27;https://api.github.com/repos/RWB0104/RWB0104.github.io/labels/prod&#x27;)]</td><td>closed</td><td>completed</td></tr><tr><td>2025-01-01T12:55:50Z</td><td>OWNER</td><td>opened</td><td>2025-01-01T12:55:49Z</td><td>[FE] 로그인</td><td>2765056166</td><td>[Row(color=&#x27;00a800&#x27;, default=False, description=&#x27;기능 개발&#x27;, id=7950417093, name=&#x27;✨feat&#x27;, node_id=&#x27;LA_kwDONSoEw88AAAAB2eG8xQ&#x27;, url=&#x27;https://api.github.com/repos/BongSangKim/FixSpeech/labels/%E2%9C%A8feat&#x27;)]</td><td>closed</td><td>completed</td></tr><tr><td>2025-01-01T12:55:54Z</td><td>OWNER</td><td>opened</td><td>2025-01-01T12:55:52Z</td><td>[FE] PWA 설정</td><td>2765056197</td><td>[Row(color=&#x27;baffc9&#x27;, default=False, description=&#x27;프론트엔드&#x27;, id=7950417303, name=&#x27;🖼frontend&#x27;, node_id=&#x27;LA_kwDONSoEw88AAAAB2eG9lw&#x27;, url=&#x27;https://api.github.com/repos/BongSangKim/FixSpeech/labels/%F0%9F%96%BCfrontend&#x27;), Row(color=&#x27;464646&#x27;, default=False, description=&#x27;테스트 작업&#x27;, id=7950417503, name=&#x27;✅test&#x27;, node_id=&#x27;LA_kwDONSoEw88AAAAB2eG-Xw&#x27;, url=&#x27;https://api.github.com/repos/BongSangKim/FixSpeech/labels/%E2%9C%85test&#x27;)]</td><td>closed</td><td>completed</td></tr><tr><td>2025-01-01T12:55:56Z</td><td>OWNER</td><td>opened</td><td>2025-01-01T12:55:55Z</td><td>[BE] FastAPI 기본 구조 생성</td><td>2765056214</td><td>[Row(color=&#x27;ffdfba&#x27;, default=False, description=&#x27;백엔드&#x27;, id=7950416460, name=&#x27;💻backend&#x27;, node_id=&#x27;LA_kwDONSoEw88AAAAB2eG6TA&#x27;, url=&#x27;https://api.github.com/repos/BongSangKim/FixSpeech/labels/%F0%9F%92%BBbackend&#x27;), Row(color=&#x27;000000&#x27;, default=False, description=&#x27;개발 환경 셋팅&#x27;, id=7950417398, name=&#x27;⚙setting&#x27;, node_id=&#x27;LA_kwDONSoEw88AAAAB2eG99g&#x27;, url=&#x27;https://api.github.com/repos/BongSangKim/FixSpeech/labels/%E2%9A%99setting&#x27;)]</td><td>closed</td><td>completed</td></tr><tr><td>2025-01-01T12:56:00Z</td><td>OWNER</td><td>opened</td><td>2025-01-01T12:55:58Z</td><td>[BE] 음성 측정 함수</td><td>2765056241</td><td>[Row(color=&#x27;ffdfba&#x27;, default=False, description=&#x27;백엔드&#x27;, i ...

# %%
# %%sparksql
# SELECT created_at, type, payload.action, payload.issue.state, payload.issue.closed_at
# FROM df
# WHERE payload.issue.id = 2764760625
# ORDER BY created_at ASC;
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">created_at</td><td style="font-weight: bold">type</td><td style="font-weight: bold">action</td><td style="font-weight: bold">state</td><td style="font-weight: bold">closed_at</td></tr><tr><td>2025-01-01T01:05:05Z</td><td>IssuesEvent</td><td>closed</td><td>closed</td><td>2025-01-01T01:05:04Z</td></tr><tr><td>2025-01-01T01:05:06Z</td><td>IssuesEvent</td><td>opened</td><td>closed</td><td>2025-01-01T01:05:04Z</td></tr></table>

# %%
# %%sparksql
# SELECT
#     payload.issue.id AS issue_id,
#     MIN(created_at) AS first_opened,
#     MAX(payload.issue.closed_at) AS final_closed,
#     TIMESTAMPDIFF(SECOND, MIN(created_at), MAX(payload.issue.closed_at)) AS resolution_time_seconds
# FROM df
# WHERE type = 'IssuesEvent'
# AND payload.issue.state = 'closed'
# AND payload.action = 'opened'
# GROUP BY payload.issue.id
# ORDER BY resolution_time_seconds DESC;
# Out:
# [Stage 14:=====================================================>  (23 + 1) / 24]
# only showing top 20 row(s)
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">issue_id</td><td style="font-weight: bold">first_opened</td><td style="font-weight: bold">final_closed</td><td style="font-weight: bold">resolution_time_seconds</td></tr><tr><td>2765057844</td><td>2025-01-01T12:59:14Z</td><td>2025-01-01T12:59:14Z</td><td>0</td></tr><tr><td>2765161495</td><td>2025-01-01T16:47:37Z</td><td>2025-01-01T16:47:37Z</td><td>0</td></tr><tr><td>2765058111</td><td>2025-01-01T12:59:44Z</td><td>2025-01-01T12:59:44Z</td><td>0</td></tr><tr><td>2764753864</td><td>2025-01-01T00:46:37Z</td><td>2025-01-01T00:46:37Z</td><td>0</td></tr><tr><td>2765058858</td><td>2025-01-01T13:01:02Z</td><td>2025-01-01T13:01:02Z</td><td>0</td></tr><tr><td>2764839439</td><td>2025-01-01T04:41:07Z</td><td>2025-01-01T04:41:07Z</td><td>0</td></tr><tr><td>2765059177</td><td>2025-01-01T13:01:38Z</td><td>2025-01-01T13:01:38Z</td><td>0</td></tr><tr><td>2764851081</td><td>2025-01-01T05:12:59Z</td><td>2025-01-01T05:12:59Z</td><td>0</td></tr><tr><td>2765078359</td><td>2025-01-01T13:40:56Z</td><td>2025-01-01T13:40:56Z</td><td>0</td></tr><tr><td>2764896188</td><td>2025-01-01T07:12:42Z</td><td>2025-01-01T07:12:42Z</td><td>0</td></tr><tr><td>2765078742</td><td>2025-01-01T13:41:41Z</td><td>2025-01-01T13:41:41Z</td><td>0</td></tr><tr><td>2765056516</td><td>2025-01-01T12:56:32Z</td><td>2025-01-01T12:56:32Z</td><td>0</td></tr><tr><td>2765102827</td><td>2025-01-01T14:33:18Z</td><td>2025-01-01T14:33:18Z</td><td>0</td></tr><tr><td>2765057279</td><td>2025-01-01T12:58:08Z</td><td>2025-01-01T12:58:08Z</td><td>0</td></tr><tr><td>2765117763</td><td>2025-01-01T15:04:58Z</td><td>2025-01-01T15:04:58Z</td><td>0</td></tr><tr><td>2765142989</td><td>2025-01-01T16:03:26Z</td><td>2025-01-01T16:03:26Z</td><td>0</td></tr><tr><td>2765157823</td><td>2025-01-01T16:38:29Z</td><td>2025-01-01T16:38:29Z</td><td>0</td></tr><tr><td>2765143370</td><td>2025-01-01T16:04:20Z</td><td>2025-01-01T16:04:20Z</td><td>0</td></tr><tr><td>2764793685</td><td>2025-01-01T02:31:17Z</td><td>2025-01-01T02:31:17Z</td><td>0</td></tr><tr><td>2765143853</td><td>2025-01-01T16:05:23Z</td><td>2025-01-01T16:05:23Z</td><td>0</td></tr></table>

# %%
# %%sparksql
# WITH opened_issues AS (
#     SELECT
#         payload.issue.id AS issue_id,
#         created_at AS opened_at
#     FROM df
#     WHERE type = 'IssuesEvent'
#       AND (payload.action = 'opened' OR payload.action = 'reopened')
# ),
#
# closed_issues AS (
#     SELECT
#         payload.issue.id AS issue_id,
#         created_at AS closed_at
#     FROM df
#     WHERE type = 'IssuesEvent'
#       AND payload.action = 'closed'
# )
#
# SELECT
#     o.issue_id,
#     o.opened_at,
#     c.closed_at,
#     TIMESTAMPDIFF(SECOND, o.opened_at, c.closed_at) AS time_to_close_seconds
# FROM opened_issues o
# JOIN closed_issues c
# ON o.issue_id = c.issue_id
# ORDER BY time_to_close_seconds ASC;
# Out:
# [Stage 22:==============================================>         (20 + 4) / 24]
# only showing top 20 row(s)
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">issue_id</td><td style="font-weight: bold">opened_at</td><td style="font-weight: bold">closed_at</td><td style="font-weight: bold">time_to_close_seconds</td></tr><tr><td>2764750585</td><td>2025-01-01T00:38:18Z</td><td>2025-01-01T23:58:06Z</td><td>83988</td></tr><tr><td>2761976744</td><td>2025-01-01T00:14:21Z</td><td>2025-01-01T23:04:30Z</td><td>82209</td></tr><tr><td>2764758445</td><td>2025-01-01T00:59:29Z</td><td>2025-01-01T23:35:21Z</td><td>81352</td></tr><tr><td>2764757468</td><td>2025-01-01T00:56:53Z</td><td>2025-01-01T23:15:13Z</td><td>80300</td></tr><tr><td>2764771640</td><td>2025-01-01T01:33:40Z</td><td>2025-01-01T23:48:17Z</td><td>80077</td></tr><tr><td>2764742246</td><td>2025-01-01T00:21:04Z</td><td>2025-01-01T22:33:16Z</td><td>79932</td></tr><tr><td>2764742305</td><td>2025-01-01T00:21:11Z</td><td>2025-01-01T22:33:23Z</td><td>79932</td></tr><tr><td>2764774114</td><td>2025-01-01T01:39:30Z</td><td>2025-01-01T23:51:03Z</td><td>79893</td></tr><tr><td>2764759266</td><td>2025-01-01T01:01:33Z</td><td>2025-01-01T22:58:47Z</td><td>79034</td></tr><tr><td>2764768065</td><td>2025-01-01T01:25:12Z</td><td>2025-01-01T23:21:31Z</td><td>78979</td></tr><tr><td>2764743446</td><td>2025-01-01T00:23:29Z</td><td>2025-01-01T22:18:57Z</td><td>78928</td></tr><tr><td>2764772812</td><td>2025-01-01T01:36:15Z</td><td>2025-01-01T22:55:51Z</td><td>76776</td></tr><tr><td>2764750811</td><td>2025-01-01T00:38:50Z</td><td>2025-01-01T21:40:30Z</td><td>75700</td></tr><tr><td>2764760191</td><td>2025-01-01T01:03:55Z</td><td>2025-01-01T22:03:29Z</td><td>75574</td></tr><tr><td>2764777940</td><td>2025-01-01T01:49:40Z</td><td>2025-01-01T22:38:19Z</td><td>74919</td></tr><tr><td>2764779551</td><td>2025-01-01T01:53:58Z</td><td>2025-01-01T22:38:20Z</td><td>74662</td></tr><tr><td>2764784016</td><td>2025-01-01T02:05:39Z</td><td>2025-01-01T22:20:05Z</td><td>72866</td></tr><tr><td>2764775882</td><td>2025-01-01T01:44:23Z</td><td>2025-01-01T21:47:10Z</td><td>72167</td></tr><tr><td>2764788860</td><td>2025-01-01T02:18:56Z</td><td>2025-01-01T22:20:40Z</td><td>72104</td></tr><tr><td>2764772708</td><td>2025-01-01T01:36:01Z</td><td>2025-01-01T21:25:05Z</td><td>71344</td></tr></table>

# %%
# %%sparksql
# WITH opened_issues AS (
#     SELECT
#         payload.issue.id AS issue_id,
#         MIN(created_at) AS opened_at  -- Pick first open event per issue
#     FROM df
#     WHERE type = 'IssuesEvent'
#       AND (payload.action = 'opened' OR payload.action = 'reopened')
#     GROUP BY payload.issue.id
# ),
#
# closed_issues AS (
#     SELECT
#         payload.issue.id AS issue_id,
#         MAX(created_at) AS closed_at  -- Pick last closed event per issue
#     FROM df
#     WHERE type = 'IssuesEvent'
#       AND payload.action = 'closed'
#     GROUP BY payload.issue.id
# )
#
# SELECT
#     o.issue_id,
#     o.opened_at,
#     c.closed_at,
#     TIMESTAMPDIFF(SECOND, o.opened_at, c.closed_at) AS time_to_close_seconds
# FROM opened_issues o
# JOIN closed_issues c
# ON o.issue_id = c.issue_id
# WHERE c.closed_at >= o.opened_at  -- Ensure closed_at is after opened_at
# ORDER BY time_to_close_seconds ASC;
# Out:
# [Stage 56:============================================>           (19 + 5) / 24]
# only showing top 20 row(s)
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">issue_id</td><td style="font-weight: bold">opened_at</td><td style="font-weight: bold">closed_at</td><td style="font-weight: bold">time_to_close_seconds</td></tr><tr><td>2764948588</td><td>2025-01-01T09:13:24Z</td><td>2025-01-01T09:13:24Z</td><td>0</td></tr><tr><td>2765232855</td><td>2025-01-01T19:50:05Z</td><td>2025-01-01T19:50:05Z</td><td>0</td></tr><tr><td>2764976428</td><td>2025-01-01T10:13:12Z</td><td>2025-01-01T10:13:12Z</td><td>0</td></tr><tr><td>2764753763</td><td>2025-01-01T00:46:18Z</td><td>2025-01-01T00:46:18Z</td><td>0</td></tr><tr><td>2765004989</td><td>2025-01-01T11:10:16Z</td><td>2025-01-01T11:10:16Z</td><td>0</td></tr><tr><td>2764812318</td><td>2025-01-01T03:24:30Z</td><td>2025-01-01T03:24:30Z</td><td>0</td></tr><tr><td>2765039832</td><td>2025-01-01T12:23:25Z</td><td>2025-01-01T12:23:25Z</td><td>0</td></tr><tr><td>2764836554</td><td>2025-01-01T04:33:26Z</td><td>2025-01-01T04:33:26Z</td><td>0</td></tr><tr><td>2765067215</td><td>2025-01-01T13:17:58Z</td><td>2025-01-01T13:17:58Z</td><td>0</td></tr><tr><td>2764844095</td><td>2025-01-01T04:53:58Z</td><td>2025-01-01T04:53:58Z</td><td>0</td></tr><tr><td>2765091026</td><td>2025-01-01T14:07:09Z</td><td>2025-01-01T14:07:09Z</td><td>0</td></tr><tr><td>2764874798</td><td>2025-01-01T06:18:43Z</td><td>2025-01-01T06:18:43Z</td><td>0</td></tr><tr><td>2765091081</td><td>2025-01-01T14:07:15Z</td><td>2025-01-01T14:07:15Z</td><td>0</td></tr><tr><td>2765117807</td><td>2025-01-01T15:05:04Z</td><td>2025-01-01T15:05:04Z</td><td>0</td></tr><tr><td>2765117843</td><td>2025-01-01T15:05:08Z</td><td>2025-01-01T15:05:08Z</td><td>0</td></tr><tr><td>2764800922</td><td>2025-01-01T02:52:43Z</td><td>2025-01-01T02:52:43Z</td><td>0</td></tr><tr><td>2765157645</td><td>2025-01-01T16:38:05Z</td><td>2025-01-01T16:38:05Z</td><td>0</td></tr><tr><td>2764830214</td><td>2025-01-01T04:15:38Z</td><td>2025-01-01T04:15:38Z</td><td>0</td></tr><tr><td>2765157659</td><td>2025-01-01T16:38:06Z</td><td>2025-01-01T16:38:06Z</td><td>0</td></tr><tr><td>2764851081</td><td>2025-01-01T05:12:59Z</td><td>2025-01-01T05:12:59Z</td><td>0</td></tr></table>

# %%
# %%sparksql
# WITH opened_issues AS (
#     SELECT
#         payload.issue.id AS issue_id,
#         MIN(created_at) AS opened_at,  -- Pick first open event per issue
#         FIRST(payload.issue.author_association) AS author_association,
#         FIRST(payload.issue.title) AS title,
#         FIRST(payload.issue.labels) AS labels,
#         FIRST(payload.issue.state) AS state,
#         FIRST(payload.issue.state_reason) AS state_reason,
#         FIRST(payload.issue.body) AS body
#     FROM df
#     WHERE type = 'IssuesEvent'
#       AND (payload.action = 'opened' OR payload.action = 'reopened')
#     GROUP BY payload.issue.id
# ),
#
# closed_issues AS (
#     SELECT
#         payload.issue.id AS issue_id,
#         MAX(created_at) AS closed_at  -- Pick last closed event per issue
#     FROM df
#     WHERE type = 'IssuesEvent'
#       AND payload.action = 'closed'
#     GROUP BY payload.issue.id
# )
#
# SELECT
#     o.issue_id,
#     o.opened_at,
#     c.closed_at,
#     TIMESTAMPDIFF(SECOND, o.opened_at, c.closed_at) AS time_to_close_seconds,
#     o.author_association,
#     o.title,
#     o.state,
#     o.state_reason,
#     o.body
# FROM opened_issues o
# JOIN closed_issues c
# ON o.issue_id = c.issue_id
# WHERE c.closed_at >= o.opened_at AND o.state != 'open' -- Ensure closed_at is after opened_at
# ORDER BY time_to_close_seconds DESC;
# Out:
# [Stage 86:==========================================>             (18 + 6) / 24]
# only showing top 20 row(s)
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">issue_id</td><td style="font-weight: bold">opened_at</td><td style="font-weight: bold">closed_at</td><td style="font-weight: bold">time_to_close_seconds</td><td style="font-weight: bold">author_association</td><td style="font-weight: bold">title</td><td style="font-weight: bold">state</td><td style="font-weight: bold">state_reason</td><td style="font-weight: bold">body</td></tr><tr><td>2765157628</td><td>2025-01-01T16:38:02Z</td><td>2025-01-01T16:38:33Z</td><td>31</td><td>NONE</td><td>issue-reopener-subdir pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1442
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572509435/attempts/1)</td></tr><tr><td>2765157618</td><td>2025-01-01T16:38:02Z</td><td>2025-01-01T16:38:32Z</td><td>30</td><td>NONE</td><td>issue-reopener-path pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1442
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572509435/attempts/1)</td></tr><tr><td>2765157679</td><td>2025-01-01T16:38:09Z</td><td>2025-01-01T16:38:38Z</td><td>29</td><td>NONE</td><td>issue-reopener-path pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1443
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572510530/attempts/1)</td></tr><tr><td>2765157609</td><td>2025-01-01T16:38:00Z</td><td>2025-01-01T16:38:27Z</td><td>27</td><td>NONE</td><td>issue-reopener-basic pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1442
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572509435/attempts/1)</td></tr><tr><td>2765157684</td><td>2025-01-01T16:38:10Z</td><td>2025-01-01T16:38:35Z</td><td>25</td><td>NONE</td><td>issue-reopener-vanityURLs pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1443
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572510530/attempts/1)</td></tr><tr><td>2765157704</td><td>2025-01-01T16:38:13Z</td><td>2025-01-01T16:38:35Z</td><td>22</td><td>NONE</td><td>issue-reopener-subdir pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1443
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572510530/attempts/1)</td></tr><tr><td>2765157757</td><td>2025-01-01T16:38:20Z</td><td>2025-01-01T16:38:36Z</td><td>16</td><td>NONE</td><td>issue-reopener-basic pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1444
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572511422/attempts/1)</td></tr><tr><td>2765161782</td><td>2025-01-01T16:48:15Z</td><td>2025-01-01T16:48:31Z</td><td>16</td><td>NONE</td><td>issue-reopener-vanityURLs pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1466
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572579639/attempts/1)</td></tr><tr><td>2765161505</td><td>2025-01-01T16:47:39Z</td><td>2025-01-01T16:47:54Z</td><td>15</td><td>NONE</td><td>issue-reopener-subdir pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1460
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572575247/attempts/1)</td></tr><tr><td>2765157823</td><td>2025-01-01T16:38:29Z</td><td>2025-01-01T16:38:44Z</td><td>15</td><td>NONE</td><td>issue-reopener-vanityURLs pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1444
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572511422/attempts/1)</td></tr><tr><td>2765161768</td><td>2025-01-01T16:48:13Z</td><td>2025-01-01T16:48:28Z</td><td>15</td><td>NONE</td><td>issue-reopener-path pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1466
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572579639/attempts/1)</td></tr><tr><td>2765161769</td><td>2025-01-01T16:48:14Z</td><td>2025-01-01T16:48:28Z</td><td>14</td><td>NONE</td><td>issue-reopener-subdir pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1466
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572579639/attempts/1)</td></tr><tr><td>2765157793</td><td>2025-01-01T16:38:25Z</td><td>2025-01-01T16:38:39Z</td><td>14</td><td>NONE</td><td>issue-reopener-path pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1444
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572511422/attempts/1)</td></tr><tr><td>2765157798</td><td>2025-01-01T16:38:26Z</td><td>2025-01-01T16:38:39Z</td><td>13</td><td>NONE</td><td>issue-reopener-subdir pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1444
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572511422/attempts/1)</td></tr><tr><td>2765161767</td><td>2025-01-01T16:48:14Z</td><td>2025-01-01T16:48:27Z</td><td>13</td><td>NONE</td><td>issue-reopener-basic pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1466
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572579639/attempts/1)</td></tr><tr><td>2765161495</td><td>2025-01-01T16:47:37Z</td><td>2025-01-01T16:47:49Z</td><td>12</td><td>NONE</td><td>issue-reopener-vanityURLs pre-submit test issue</td><td>closed</td><td>completed</td><td>Test issue for commit  https://github.com/ianlewis/todo-issue-reopener/pull/1460
# - [Workflow run](https://github.com/ianlewis/todo-issue-reopener/actions/runs/12572575247/attempts/1)</td></tr><tr><td>2764896188</td><td>2025-01-01T07:12:42Z</td><td>2025-01-01T07:12:43Z</td><td>1</td><td>OWNER</td><td>🚨 Error Report - 2025. 01. 01. 07:12:41</td><td>closed</td><td>completed</td><td>
# &lt;p align=&quot;center&quot;&gt;&lt;img src=&quot;https://project.itcode.dev/favicon.ico&quot; width=&quot;128&quot; height=&quot;128&quot; /&gt;&lt;/p&gt;
#
# &lt;h1 align=&quot;center&quot;&gt;Project Health Report&lt;/h1&gt;
# &lt;p align=&quot;center&quot;&gt;at 2025. 01. 01. 07:12:41&lt;/p&gt;
#
# &lt;br /&gt;
# &lt;br /&gt;
#
# ## 👽 API
#
# &lt;p&gt;
# &lt;span&gt;✅ [200] JADER&lt;/span&gt;
# &lt;a href=&quot;https://api.itcode.dev/jader/api/ping&quot; target=&quot;_blank&quot; style=&quot;font-size: 12px;&quot;&gt;https://api.itcode.dev/jader/api/ping&lt;/a&gt;
# &lt;/p&gt;&lt;p&gt;
# &lt;span&gt;✅ [200] OpenLayers Box&lt;/span&gt;
# &lt;a href=&quot;https://api.itcode.dev/geoserver&quot; target=&quot;_blank&quot; style=&quot;font-size: 12px;&quot;&gt;https://api.itcode.dev/geoserver&lt;/a&gt;
# &lt;/p&gt;&lt;p&gt;
# &lt;span&gt;✅ [204] KAKAO STYLE&lt;/span&gt;
# &lt;a href=&quot;https://api.itcode.dev/kakaostyle/api/ping&quot; target=&quot;_blank&quot; style=&quot;font-size: 12px;&quot;&gt;https://api.itcode.dev/kakaostyle/api/ping&lt;/a&gt;
# &lt;/p&gt;&lt;p&gt;
# &lt;span&gt;✅ [204] KLID&lt;/span&gt;
# &lt;a href=&quot;https://api.itcode.dev/klid/api/ping&quot; target=&quot;_blank
